# %% [markdown]
# ## PT4.2-Decision Tree
#
# **AI Bootcamp - Instinct Institute**
#
# **Author:** MORK Mongkul

# %% [markdown]
# ## Exercise 1: Titanic Dataset
#
# ### Objective
# - Learn how to build a decision tree classifier.
# - Understand handling of categorical and numerical features.
# - Visualize the decision tree and interpret splits.
#
# ### Dataset
# - Titanic dataset: https://raw.githubusercontent.com/MorkMongkul/AI-Bootcamp-Instinct/main/Data/Titanic-Dataset.csv
# - Features: `pclass`, `sex`, `age`, `fare`, `sibsp`, `parch`, `embarked`
# - Target: `survived` (0 = Not Survived, 1 = Survived)

# %% [markdown]
# **Imports Libraries**

# %%
#To Do

# %% [markdown]
# **Load Dataset**

# %%
#To Do

# %% [markdown]
# **Data Preprocessing**
#
# - Handling missing values
#
# - Encode Categorical variables
#
# - split data

# %%
#To Do

# %% [markdown]
# **Model Training**

# %%
#To Do

# %% [markdown]
# **Prediction and Evaluation**

# %%
#To Do

# %% [markdown]
# **Plot Decision Tree**

# %%
#To Do

# %% [markdown]
# ## Exercise2: Wine Dataset – Classify Wine Type
#
#
# ### Objective
# - Build a decision tree classifier for multi-class classification.
#
# - Explore feature importance in decision trees.
#
# - Understand how numerical features influence splits.
#
# ### Dataset
# - Wine dataset: https://raw.githubusercontent.com/MorkMongkul/AI-Bootcamp-Instinct/main/Data/WineQT.csv
#
# - Features: All 13 chemical properties (`alcohol`, `malic_acid`, `ash`, etc.)
#
# - Target: `target` (0, 1, 2 = Wine class)

# %%
#To Do
